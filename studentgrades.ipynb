# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/admin/Desktop/tanuja1/student_grades.csv')

# %%
print(df.head(8))
# Out:
#    ID    Name gender  age  study_hours  attendance(%)  marks_math  \
# 0   1    riya      f   17          3.5             95          88
# 1   2   arjun      m   18          2.0             82          75
# 2   3   sneha      f   17          4.0             98          90
# 3   4  rakesh      m   19          1.5             70          65
# 4   5  adithi      f   18          3.8             92          95
# 5   6   kiran      m   18          2.5             85          78
# 6   7  anjali      f   17          4.5             99          91
# 7   8  manish      m   19          1.0             65          60
#
#    marks_science grade
# 0             92     A
# 1             80     B
# 2             89     A
# 3             68     C
# 4             93     A
# 5             75     B
# 6             95     A
# 7             58     D

# %%
plt.title("students table")
plt.xlabel("stedent marks_math")
plt.ylabel("frequency")
plt.hist(df['marks_math'])
plt.show()

# %%
df['grade'].value_counts().plot(kind='bar',x='grade',y='ID')
# Out:
# <AxesSubplot:>

# %%
plt.title("students table")
plt.xlabel("stedent study_hours")
plt.ylabel("frequency")
plt.hist(df['study_hours'])
plt.show()

# %%
plt.boxplot(df['study_hours'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a645c5ed60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a645c6f460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a645c5e970>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a645c6fb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a645c6fe80>],
#  'means': []}

# %%
plt.pie(df['gender'].value_counts(),autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2a645e2b790>,
# ...
#  [Text(6.735557395310444e-17, 1.1, ''),
#   Text(-2.0206672185931328e-16, -1.1, '')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.1021821192326178e-16, -0.6, '50.0%')])

# %%
plt.hist(df['attendance(%)'])
plt.show()

# %%
plt.xlabel("study_hours")
plt.ylabel("study_hours")
plt.scatter(df['study_hours'],df['marks_math'])

# %%
plt.scatter(df['attendance(%)'],df['marks_science'])

# %%
marks=df.groupby('gender')['marks_math'].mean()
plt.bar(marks.index,marks.values)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.plot(df['Name'],df[['marks_math','marks_science']])
plt.show()

# %%
df.boxplot(column='marks_math',by='grade')
# Out:
# <AxesSubplot:title={'center':'marks_math'}, xlabel='grade'>
